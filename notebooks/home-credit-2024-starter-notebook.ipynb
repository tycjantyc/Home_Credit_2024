# %% [markdown]
# # Example Notebook
#
# Welcome to the example notebook for the Home Credit Kaggle competition. The goal of this competition is to determine how likely a customer is going to default on an issued loan. The main difference between the [first](https://www.kaggle.com/c/home-credit-default-risk) and this competition is that now your submission will be scored with a custom metric that will take into account how well the model performs in future. A decline in performance will be penalized. The goal is to create a model that is stable and performs well in the future.
#
# In this notebook you will see how to:
# * Load the data
# * Join tables with Polars - a DataFrame library implemented in Rust language, designed to be blazingy fast and memory efficient.
# * Create simple aggregation features
# * Train a LightGBM model
# * Create a submission table
#
# ## Load the data

# %%
import polars as pl
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score 

dataPath = "../"

# %%
def set_table_dtypes(df: pl.DataFrame) -> pl.DataFrame:
    # implement here all desired dtypes for tables
    # the following is just an example
    for col in df.columns:
        # last letter of column name will help you determine the type
        if col[-1] in ("P", "A"):
            df = df.with_columns(pl.col(col).cast(pl.Float64).alias(col))

    return df

def convert_strings(df: pd.DataFrame) -> pd.DataFrame:
    for col in df.columns:  
        if df[col].dtype.name in ['object', 'string']:
            df[col] = df[col].astype("string").astype('category')
            current_categories = df[col].cat.categories
            new_categories = current_categories.to_list() + ["Unknown"]
            new_dtype = pd.CategoricalDtype(categories=new_categories, ordered=True)
            df[col] = df[col].astype(new_dtype)
    return df

# %%
train_basetable = pl.read_csv(dataPath + "csv_files/train/train_base.csv")
train_static = pl.concat(
    [
        pl.read_csv(dataPath + "csv_files/train/train_static_0_0.csv").pipe(set_table_dtypes),
        pl.read_csv(dataPath + "csv_files/train/train_static_0_1.csv").pipe(set_table_dtypes),
    ],
    how="vertical_relaxed",
)
train_static_cb = pl.read_csv(dataPath + "csv_files/train/train_static_cb_0.csv").pipe(set_table_dtypes)
train_person_1 = pl.read_csv(dataPath + "csv_files/train/train_person_1.csv").pipe(set_table_dtypes) 
train_credit_bureau_b_2 = pl.read_csv(dataPath + "csv_files/train/train_credit_bureau_b_2.csv").pipe(set_table_dtypes)

# %%
train_basetable
# Out:
# shape: (1_526_659, 5)
# ┌─────────┬───────────────┬────────┬──────────┬────────┐
# │ case_id ┆ date_decision ┆ MONTH  ┆ WEEK_NUM ┆ target │
# │ ---     ┆ ---           ┆ ---    ┆ ---      ┆ ---    │
# │ i64     ┆ str           ┆ i64    ┆ i64      ┆ i64    │
# ╞═════════╪═══════════════╪════════╪══════════╪════════╡
# │ 0       ┆ 2019-01-03    ┆ 201901 ┆ 0        ┆ 0      │
# │ 1       ┆ 2019-01-03    ┆ 201901 ┆ 0        ┆ 0      │
# │ 2       ┆ 2019-01-04    ┆ 201901 ┆ 0        ┆ 0      │
# │ 3       ┆ 2019-01-03    ┆ 201901 ┆ 0        ┆ 0      │
# │ 4       ┆ 2019-01-04    ┆ 201901 ┆ 0        ┆ 1      │
# │ …       ┆ …             ┆ …      ┆ …        ┆ …      │
# │ 2703450 ┆ 2020-10-05    ┆ 202010 ┆ 91       ┆ 0      │
# │ 2703451 ┆ 2020-10-05    ┆ 202010 ┆ 91       ┆ 0      │
# │ 2703452 ┆ 2020-10-05    ┆ 202010 ┆ 91       ┆ 0      │
# │ 2703453 ┆ 2020-10-05    ┆ 202010 ┆ 91       ┆ 0      │
# │ 2703454 ┆ 2020-10-05    ┆ 202010 ┆ 91       ┆ 0      │
# └─────────┴───────────────┴────────┴──────────┴────────┘

# %%
train = [train_basetable, train_static, train_static_cb, train_person_1, train_credit_bureau_b_2]
suma = 0

for i in train:
    suma += len(i.columns)
    print(len(i.columns))

print(f"Total: {suma}")
# Out:
# 5
# 168
# 53
# 37
# 6
# Total: 269

# %%
columns_names = []
ranges = []
types = []

for i in train:
    for col in i.columns:
        columns_names.append(col)
        ranges.append((i[col].min(),i[col].max())) 
        types.append(i[col].dtype)

df = pd.DataFrame(list(zip(columns_names, ranges, types)), columns = ["column name", "range", "types"])

# %%
print(df.to_string())
# Out:
#                          column name                          range    types
# 0                            case_id                   (0, 2703454)    Int64
# 1                      date_decision       (2019-01-01, 2020-10-05)   String
# 2                              MONTH               (201901, 202010)    Int64
# 3                           WEEK_NUM                        (0, 91)    Int64
# 4                             target                         (0, 1)    Int64
# 5                            case_id                   (0, 2703454)    Int64
# 6            actualdpdtolerance_344P                  (0.0, 4206.0)  Float64
# 7     amtinstpaidbefduel24m_4187115A               (0.0, 1408010.2)  Float64
# 8                       annuity_780A               (80.8, 106007.0)  Float64
# 9               annuitynextmonth_57A                 (0.0, 87500.0)  Float64
# 10               applicationcnt_361L                     (0.0, 5.0)  Float64
# 11              applications30d_658L                    (0.0, 28.0)  Float64
# 12             applicationscnt_1086L                   (0.0, 728.0)  Float64
# 13              applicationscnt_464L                   (0.0, 247.0)  Float64
# 14              applicationscnt_629L                    (0.0, 90.0)  Float64
# 15              applicationscnt_867L                   (0.0, 287.0)  Float64
# 16         avgdbddpdlast24m_3658932P              (-1220.0, 4750.0)  Float64
# 17          avgdbddpdlast3m_4187120P               (-908.0, 4750.0)  Float64
# 18         avgdbdtollast24m_4525197P              (-1220.0, 4750.0)  Float64
# 19       avgdpdtolclosure24_3658938P                  (0.0, 4750.0)  Float64
# 20         avginstallast24m_3658937A                (0.0, 496148.8)  Float64
# 21         avglnamtstart24m_4525187A                (0.0, 513520.0)  Float64
# 22          avgmaxdpdlast9m_3716943P                   (0.0, 240.0)  Float64
# 23    avgoutstandbalancel6m_4187114A        (-7588198.5, 1131135.9)  Float64
# 24            avgpmtlast12m_4525200A                (0.0, 495910.4)  Float64
# 25                  bankacctype_710L                       (CA, CA)   String
# 26                      cardtype_51L        (INSTANT, PERSONALIZED)   String
# 27            clientscnt12m_3712952L                   (0.0, 198.0)  Float64
# 28             clientscnt3m_3712950L                   (0.0, 112.0)  Float64
# 29             clientscnt6m_3712949L                   (0.0, 175.0)  Float64
# 30                   clientscnt_100L                   (0.0, 109.0)  Float64
# 31                  clientscnt_1022L                   (0.0, 266.0)  Float64
# 32                  clientscnt_1071L                    (0.0, 24.0)  Float64
# 33                  clientscnt_1130L                    (0.0, 35.0)  Float64
# 34                   clientscnt_136L                     (0.0, 4.0)   String
# 35                   clientscnt_157L                   (0.0, 390.0)  Float64
# 36                   clientscnt_257L                    (0.0, 13.0)  Float64
# 37                   clientscnt_304L                   (0.0, 510.0)  Float64
# 38                   clientscnt_360L                    (0.0, 15.0)  Float64
# 39                   clientscnt_493L                   (0.0, 922.0)  Float64
# 40                   clientscnt_533L                    (0.0, 12.0)  Float64
# 41                   clientscnt_887L                  (0.0, 1242.0)  Float64
# 42                   clientscnt_946L                    (0.0, 72.0)  Float64
# 43          cntincpaycont9m_3716944L                   (0.0, 575.0)  Float64
# 44                cntpmts24_3658933L                    (0.0, 25.0)  Float64
# 45          commnoinclast6m_3546845L                     (0.0, 0.0)  Float64
# 46                   credamount_770A             (2000.0, 950000.0)  Float64
# 47                     credtype_322L                     (CAL, REL)   String
# 48                      currdebt_22A               (0.0, 1210629.1)  Float64
# 49        currdebtcredtyperange_828A               (0.0, 1029392.8)  Float64
# 50              datefirstoffer_1144D       (2007-04-30, 2020-06-22)   String
# 51          datelastinstal40dpd_247D       (2006-02-04, 2020-09-06)   String
# 52           datelastunpaid_3546854D       (2006-02-08, 2020-10-18)   String
# 53   daysoverduetolerancedd_3976961L                  (0.0, 5337.0)  Float64
# 54             deferredmnthsnum_166L                     (0.0, 0.0)  Float64
# 55         disbursedcredamount_1113A                (0.0, 950000.0)  Float64
# 56              disbursementtype_67L                      (DD, SBA)   String
# 57                      downpmt_116A                (0.0, 461867.4)  Float64
# 58         dtlastpmtallstes_4499206D       (2006-02-22, 2020-10-18)   String
# 59                          eir_270L                    (0.0, 0.45)  Float64
# 60        equalitydataagreement_891L                  (False, True)  Boolean
# 61               equalityempfrom_62L                  (False, True)  Boolean
# 62            firstclxcampaign_1125D       (2016-01-31, 2020-06-23)   String
# 63                 firstdatedue_489D       (2006-01-06, 2020-11-11)   String
# 64                   homephncnt_628L                    (0.0, 14.0)  Float64
# 65        inittransactionamount_650A                (0.0, 200000.0)  Float64
# 66          inittransactioncode_186L                    (CASH, POS)   String
# 67                 interestrate_311L                    (0.0, 0.45)  Float64
# 68             interestrategrace_34L                     (0.0, 0.0)  Float64
# 69                isbidproduct_1095L                  (False, True)  Boolean
# 70          isbidproductrequest_292L                  (False, true)   String
# 71                  isdebitcard_729L                 (False, False)  Boolean
# 72            lastactivateddate_801D       (2006-01-08, 2020-10-19)   String
# 73          lastapplicationdate_877D       (2006-01-03, 2020-10-19)   String
# 74        lastapprcommoditycat_1041M        (P100_96_175, a55475b1)   String
# 75   lastapprcommoditytypec_5251766M       (P100_118_186, a55475b1)   String
# 76           lastapprcredamount_781A                (0.0, 400000.0)  Float64
# 77                 lastapprdate_640D       (2006-01-07, 2020-10-19)   String
# 78             lastcancelreason_561M       (P107_145_100, a55475b1)   String
# 79               lastdelinqdate_224D       (2006-08-19, 2020-10-18)   String
# 80            lastdependentsnum_448L                     (0.0, 9.0)   String
# 81                 lastotherinc_902A                 (0.0, 30000.0)  Float64
# 82          lastotherlnsexpense_631A                (0.0, 270000.0)  Float64
# 83       lastrejectcommoditycat_161M        (P100_96_175, a55475b1)   String
# 84    lastrejectcommodtypec_5251769M       (P100_118_186, a55475b1)   String
# 85         lastrejectcredamount_222A               (0.0, 1000000.0)  Float64
# 86                lastrejectdate_50D       (2006-01-03, 2020-10-19)   String
# 87             lastrejectreason_759M        (P121_60_164, a55475b1)   String
# 88   lastrejectreasonclient_4145040M        (P129_162_80, a55475b1)   String
# 89             lastrepayingdate_696D       (2007-04-05, 2020-10-18)   String
# 90                       lastst_736L                         (A, T)   String
# 91                      maininc_215A                (0.0, 200000.0)  Float64
# 92        mastercontrelectronic_519L                     (0.0, 0.0)  Float64
# 93             mastercontrexist_109L                     (0.0, 0.0)  Float64
# 94                   maxannuity_159A              (0.0, 20923088.0)  Float64
# 95               maxannuity_4075009A              (600.0, 601320.0)  Float64
# 96          maxdbddpdlast1m_3658939P              (-1237.0, 4804.0)  Float64
# 97      maxdbddpdtollast12m_3658940P              (-1199.0, 4804.0)  Float64
# 98       maxdbddpdtollast6m_4187119P              (-1225.0, 4804.0)  Float64
# 99                     maxdebt4_972A               (0.0, 1740000.0)  Float64
# 100       maxdpdfrom6mto36m_3546853P                  (0.0, 4465.0)  Float64
# 101         maxdpdinstldate_3546855D       (2006-02-07, 2020-10-18)   String
# 102          maxdpdinstlnum_3546846P                   (0.0, 105.0)  Float64
# 103               maxdpdlast12m_727P                  (0.0, 4629.0)  Float64
# 104               maxdpdlast24m_143P                  (0.0, 4629.0)  Float64
# 105                maxdpdlast3m_392P                  (0.0, 4629.0)  Float64
# 106                maxdpdlast6m_474P                  (0.0, 4629.0)  Float64
# 107               maxdpdlast9m_1059P                  (0.0, 4629.0)  Float64
# 108             maxdpdtolerance_374P                  (0.0, 4629.0)  Float64
# 109        maxinstallast24m_3658928A               (0.0, 1009600.8)  Float64
# 110         maxlnamtstart6m_4525199A                (0.0, 518629.6)  Float64
# 111  maxoutstandbalancel12m_4187113A        (-7588198.5, 1235312.9)  Float64
# 112            maxpmtlast3m_4525190A                (0.0, 538113.0)  Float64
# 113        mindbddpdlast24m_3658935P              (-1284.0, 4709.0)  Float64
# 114        mindbdtollast24m_4525191P              (-1284.0, 4709.0)  Float64
# 115                mobilephncnt_593L                    (0.0, 23.0)  Float64
# 116               monthsannuity_845L                   (0.0, 167.0)  Float64
# 117              numactivecreds_622L                     (0.0, 7.0)  Float64
# 118       numactivecredschannel_414L                     (0.0, 4.0)  Float64
# 119           numactiverelcontr_750L                     (0.0, 8.0)  Float64
# 120            numcontrs3months_479L                    (0.0, 58.0)  Float64
# 121         numincomingpmts_3546848L                   (0.0, 843.0)  Float64
# 122      numinstlallpaidearly3d_817L                   (0.0, 377.0)  Float64
# 123                   numinstls_657L                   (0.0, 448.0)  Float64
# 124            numinstlsallpaid_934L                   (0.0, 385.0)  Float64
# 125          numinstlswithdpd10_728L                   (0.0, 330.0)  Float64
# 126       numinstlswithdpd5_4187116L                     (0.0, 9.0)   String
# 127         numinstlswithoutdpd_562L                   (0.0, 861.0)  Float64
# 128  numinstmatpaidtearly2d_4499204L                    (0.0, 99.0)   String
# 129             numinstpaid_4499208L                    (0.0, 99.0)   String
# 130      numinstpaidearly3d_3546850L                   (0.0, 373.0)  Float64
# 131   numinstpaidearly3dest_4493216L                    (0.0, 99.0)   String
# 132         numinstpaidearly5d_1087L                   (0.0, 278.0)  Float64
# 133   numinstpaidearly5dest_4493211L                     (0.0, 9.0)   String
# 134   numinstpaidearly5dobd_4499205L                    (0.0, 99.0)   String
# 135            numinstpaidearly_338L                   (0.0, 373.0)  Float64
# 136     numinstpaidearlyest_4493214L                    (0.0, 99.0)   String
# 137    numinstpaidlastcontr_4325080L                     (0.0, 9.0)   String
# 138       numinstpaidlate1d_3546852L                   (0.0, 137.0)  Float64
# 139          numinstregularpaid_973L                   (0.0, 393.0)  Float64
# 140   numinstregularpaidest_4493210L                    (0.0, 99.0)   String
# 141              numinsttopaygr_769L                   (0.0, 152.0)  Float64
# 142       numinsttopaygrest_4493213L                    (0.0, 99.0)   String
# 143        numinstunpaidmax_3546851L                    (0.0, 72.0)  Float64
# 144     numinstunpaidmaxest_4493212L                     (0.0, 9.0)   String
# 145            numnotactivated_1143L                     (0.0, 4.0)  Float64
# 146             numpmtchanneldd_318L                     (0.0, 4.0)  Float64
# 147                numrejects9m_859L                   (0.0, 153.0)  Float64
# 148                    opencred_647L                  (False, True)  Boolean
# 149                  paytype1st_925L                 (OTHER, OTHER)   String
# 150                     paytype_783L                 (OTHER, OTHER)   String
# 151     payvacationpostpone_4187118D       (2018-03-28, 2020-10-13)   String
# 152      pctinstlsallpaidearl3d_427L                    (0.0, 23.0)  Float64
# 153      pctinstlsallpaidlat10d_839L                 (0.0, 1.11111)  Float64
# 154  pctinstlsallpaidlate1d_3546856L                     (0.0, 1.0)  Float64
# 155  pctinstlsallpaidlate4d_3546849L                     (0.0, 2.0)  Float64
# 156  pctinstlsallpaidlate6d_3546844L                     (0.0, 1.0)  Float64
# 157                      pmtnum_254L                    (3.0, 60.0)  Float64
# 158           posfpd10lastmonth_333P                     (0.0, 1.0)  Float64
# 159       posfpd30lastmonth_3976960P                     (0.0, 1.0)  Float64
# 160    posfstqpd30lastmonth_3976962P                     (0.0, 1.0)  Float64
# 161        previouscontdistrict_112M         (P0_140_162, a55475b1)   String
# 162                      price_1097A               (0.0, 761867.44)  Float64
# 163              sellerplacecnt_915L                     (0.0, 8.0)  Float64
# 164             sellerplacescnt_216L                   (0.0, 102.0)  Float64
# 165        sumoutstandtotal_3546847A          (-25044.0, 1210629.1)  Float64
# 166     sumoutstandtotalest_4493215A          (-25044.0, 1085048.1)  Float64
# 167                     totaldebt_9A               (0.0, 1210629.1)  Float64
# 168                totalsettled_863A              (0.0, 48035036.0)  Float64
# 169         totinstallast1m_4525188A         (0.21400002, 794899.2)  Float64
# 170               twobodfilling_608L                       (BO, FO)   String
# 171                   typesuite_864L                       (AL, AL)   String
# 172                  validfrom_1069D       (2018-09-22, 2020-06-22)   String
# 173                          case_id                 (357, 2703454)    Int64
# 174              assignmentdate_238D       (1974-05-30, 2019-10-22)   String
# 175          assignmentdate_4527235D       (2019-09-13, 2020-10-19)   String
# 176          assignmentdate_4955616D       (1984-12-05, 2020-09-22)   String
# 177                   birthdate_574D       (1943-03-01, 1998-09-01)   String
# 178            contractssum_5085716L               (0.0, 999983.29)   String
# 179                 dateofbirth_337D       (1900-01-01, 2020-01-01)   String
# 180                 dateofbirth_342D       (1915-01-01, 2015-09-01)   String
# 181                     days120_123L                   (0.0, 109.0)  Float64
# 182                     days180_256L                   (0.0, 110.0)  Float64
# 183                      days30_165L                    (0.0, 22.0)  Float64
# 184                     days360_512L                   (0.0, 115.0)  Float64
# 185                      days90_310L                    (0.0, 41.0)  Float64
# 186             description_5085714M           (2fc785b2, a55475b1)   String
# 187                  education_1103M           (39a0853f, c8e1a1d0)   String
# 188                    education_88M           (6b2ae0fa, c8e1a1d0)   String
# 189                firstquarter_103L                    (0.0, 76.0)  Float64
# 190                   for3years_128L                     (0.0, 1.0)  Float64
# 191                   for3years_504L                    (0.0, 57.0)  Float64
# 192                   for3years_584L                     (0.0, 2.0)  Float64
# 193                    formonth_118L                     (0.0, 0.0)  Float64
# 194                    formonth_206L                     (0.0, 1.0)  Float64
# 195                    formonth_535L                    (0.0, 11.0)  Float64
# 196                 forquarter_1017L                     (0.0, 2.0)  Float64
# 197                  forquarter_462L                     (0.0, 0.0)  Float64
# 198                  forquarter_634L                    (0.0, 19.0)  Float64
# 199                   fortoday_1092L                     (0.0, 2.0)  Float64
# 200                    forweek_1077L                     (0.0, 1.0)  Float64
# 201                     forweek_528L                     (0.0, 4.0)  Float64
# 202                     forweek_601L                     (0.0, 0.0)  Float64
# 203                     foryear_618L                     (0.0, 1.0)  Float64
# 204                     foryear_818L                     (0.0, 2.0)  Float64
# 205                     foryear_850L                    (0.0, 41.0)  Float64
# 206               fourthquarter_440L                    (0.0, 66.0)  Float64
# 207                   maritalst_385M           (3439d993, ecd83604)   String
# 208                   maritalst_893M           (1a19667c, ecd83604)   String
# 209             numberofqueries_373L                   (0.0, 115.0)  Float64
# 210                    pmtaverage_3A                (0.0, 145257.4)  Float64
# 211              pmtaverage_4527227A         (4.2000003, 205848.61)  Float64
# 212              pmtaverage_4955615A                 (4.4, 99085.4)  Float64
# 213                pmtcount_4527229L                     (1.0, 9.0)   String
# 214                pmtcount_4955617L                     (1.0, 9.0)   String
# 215                    pmtcount_693L                    (0.0, 66.0)  Float64
# 216                   pmtscount_423L                   (0.0, 121.0)  Float64
# 217                      pmtssum_45A                (0.0, 476843.4)  Float64
# 218             requesttype_4525192L        (DEDUCTION_6, SOCIAL_6)   String
# 219               responsedate_1012D       (2019-01-02, 2019-10-22)   String
# 220            responsedate_4527233D       (2019-09-13, 2020-10-19)   String
# 221            responsedate_4917613D       (2020-03-26, 2020-10-19)   String
# 222               riskassesment_302T            (1% - 1%, 8% - 11%)   String
# 223               riskassesment_940T        (-3.6704228, 2.1191318)  Float64
# 224               secondquarter_766L                   (0.0, 109.0)  Float64
# 225               thirdquarter_1082L                    (0.0, 62.0)  Float64
# 226                          case_id                   (0, 2703454)    Int64
# 227                       birth_259D       (1943-03-01, 1999-10-01)   String
# 228                    birthdate_87D       (1911-12-01, 2015-12-01)   String
# 229                    childnum_185L                    (0.0, 11.0)  Float64
# 230            contaddr_district_15M         (P0_111_121, a55475b1)   String
# 231         contaddr_matchlist_1032L                 (False, False)  Boolean
# 232         contaddr_smempladdr_334L                  (False, True)  Boolean
# 233            contaddr_zipcode_807M          (P0_101_75, a55475b1)   String
# 234                   education_927M        (P106_81_188, a55475b1)   String
# 235           empl_employedfrom_271D       (1963-06-15, 2020-09-15)   String
# 236          empl_employedtotal_800L           (LESS_ONE, MORE_ONE)   String
# 237               empl_industry_691L         (AGRICULTURE, WELNESS)   String
# 238           empladdr_district_926M         (P0_140_162, a55475b1)   String
# 239            empladdr_zipcode_114M          (P0_101_75, a55475b1)   String
# 240                 familystate_447L            (DIVORCED, WIDOWED)   String
# 241                      gender_992L                         (F, M)   String
# 242                   housetype_905L     (COMPANY_FLAT, STATE_FLAT)   String
# 243                 housingtype_772L     (COMPANY_FLAT, STATE_FLAT)   String
# 244                 incometype_1044T       (EMPLOYED, SELFEMPLOYED)   String
# 245                 isreference_387L                  (False, True)  Boolean
# 246                   language1_981M         (P10_39_147, a55475b1)   String
# 247           mainoccupationinc_384A                (0.0, 200000.0)  Float64
# 248                   maritalst_703L            (DIVORCED, WIDOWED)   String
# 249                       num_group1                         (0, 9)    Int64
# 250                personindex_1023L                     (0.0, 6.0)  Float64
# 251                 persontype_1072L                     (1.0, 5.0)  Float64
# 252                  persontype_792L                     (1.0, 5.0)  Float64
# 253        registaddr_district_1083M         (P0_111_121, a55475b1)   String
# 254          registaddr_zipcode_184M          (P0_101_75, a55475b1)   String
# 255        relationshiptoclient_415T                (CHILD, SPOUSE)   String
# 256        relationshiptoclient_642T                (CHILD, SPOUSE)   String
# 257                    remitter_829L                 (False, False)  Boolean
# 258                       role_1084L                       (CL, PE)   String
# 259                        role_993L                   (FULL, FULL)   String
# 260            safeguarantyflag_411L                  (False, True)  Boolean
# 261                         sex_738L                         (F, M)   String
# 262                         type_25L  (ALTERNATIVE_PHONE, WHATSAPP)   String
# 263                          case_id                 (467, 2703436)    Int64
# 264                       num_group1                        (0, 20)    Int64
# 265                       num_group2                        (0, 36)    Int64
# 266                  pmts_date_1107D       (2016-01-15, 2020-10-15)   String
# 267               pmts_dpdvalue_108P             (0.0, 185124192.0)  Float64
# 268            pmts_pmtsoverdue_635A               (0.0, 147470.61)  Float64

# %%
print(df["types"].value_counts())
# Out:
# Float64    155
# String      93
# Int64       11
# Boolean     10
# Name: types, dtype: int64

# %%
test_basetable = pl.read_csv(dataPath + "csv_files/test/test_base.csv")
test_static = pl.concat(
    [
        pl.read_csv(dataPath + "csv_files/test/test_static_0_0.csv").pipe(set_table_dtypes),
        pl.read_csv(dataPath + "csv_files/test/test_static_0_1.csv").pipe(set_table_dtypes),
        pl.read_csv(dataPath + "csv_files/test/test_static_0_2.csv").pipe(set_table_dtypes),
    ],
    how="vertical_relaxed",
)
test_static_cb = pl.read_csv(dataPath + "csv_files/test/test_static_cb_0.csv").pipe(set_table_dtypes)
test_person_1 = pl.read_csv(dataPath + "csv_files/test/test_person_1.csv").pipe(set_table_dtypes) 
test_credit_bureau_b_2 = pl.read_csv(dataPath + "csv_files/test/test_credit_bureau_b_2.csv").pipe(set_table_dtypes)

# %% [markdown]
# ## Feature engineering
#
# In this part, we can see a simple example of joining tables via `case_id`. Here the loading and joining is done with polars library. Polars library is blazingly fast and has much smaller memory footprint than pandas.

# %%
# We need to use aggregation functions in tables with depth > 1, so tables that contain num_group1 column or 
# also num_group2 column.
train_person_1_feats_1 = train_person_1.group_by("case_id").agg(
    pl.col("mainoccupationinc_384A").max().alias("mainoccupationinc_384A_max"),
    (pl.col("incometype_1044T") == "SELFEMPLOYED").max().alias("mainoccupationinc_384A_any_selfemployed")
)

# Here num_group1=0 has special meaning, it is the person who applied for the loan.
train_person_1_feats_2 = train_person_1.select(["case_id", "num_group1", "housetype_905L"]).filter(
    pl.col("num_group1") == 0
).drop("num_group1").rename({"housetype_905L": "person_housetype"})

# Here we have num_goup1 and num_group2, so we need to aggregate again.
train_credit_bureau_b_2_feats = train_credit_bureau_b_2.group_by("case_id").agg(
    pl.col("pmts_pmtsoverdue_635A").max().alias("pmts_pmtsoverdue_635A_max"),
    (pl.col("pmts_dpdvalue_108P") > 31).max().alias("pmts_dpdvalue_108P_over31")
)

# We will process in this examples only A-type and M-type columns, so we need to select them.
selected_static_cols = []
for col in train_static.columns:
    if col[-1] in ("A", "M"):
        selected_static_cols.append(col)
print(selected_static_cols)

selected_static_cb_cols = []
for col in train_static_cb.columns:
    if col[-1] in ("A", "M"):
        selected_static_cb_cols.append(col)
print(selected_static_cb_cols)

# Join all tables together.
data = train_basetable.join(
    train_static.select(["case_id"]+selected_static_cols), how="left", on="case_id"
).join(
    train_static_cb.select(["case_id"]+selected_static_cb_cols), how="left", on="case_id"
).join(
    train_person_1_feats_1, how="left", on="case_id"
).join(
    train_person_1_feats_2, how="left", on="case_id"
).join(
    train_credit_bureau_b_2_feats, how="left", on="case_id"
)
# Out:
# ['amtinstpaidbefduel24m_4187115A', 'annuity_780A', 'annuitynextmonth_57A', 'avginstallast24m_3658937A', 'avglnamtstart24m_4525187A', 'avgoutstandbalancel6m_4187114A', 'avgpmtlast12m_4525200A', 'credamount_770A', 'currdebt_22A', 'currdebtcredtyperange_828A', 'disbursedcredamount_1113A', 'downpmt_116A', 'inittransactionamount_650A', 'lastapprcommoditycat_1041M', 'lastapprcommoditytypec_5251766M', 'lastapprcredamount_781A', 'lastcancelreason_561M', 'lastotherinc_902A', 'lastotherlnsexpense_631A', 'lastrejectcommoditycat_161M', 'lastrejectcommodtypec_5251769M', 'lastrejectcredamount_222A', 'lastrejectreason_759M', 'lastrejectreasonclient_4145040M', 'maininc_215A', 'maxannuity_159A', 'maxannuity_4075009A', 'maxdebt4_972A', 'maxinstallast24m_3658928A', 'maxlnamtstart6m_4525199A', 'maxoutstandbalancel12m_4187113A', 'maxpmtlast3m_4525190A', 'previouscontdistrict_112M', 'price_1097A', 'sumoutstandtotal_3546847A', 'sumoutstandtotalest_4493215A', 'totaldebt_9A', 'totalsettled_863A', 'totinstallast1m_4525188A']
# ['description_5085714M', 'education_1103M', 'education_88M', 'maritalst_385M', 'maritalst_893M', 'pmtaverage_3A', 'pmtaverage_4527227A', 'pmtaverage_4955615A', 'pmtssum_45A']

# %%
d = pd.DataFrame(list(zip(data.columns, data.dtypes)), columns=["columns", "types"])
d['types'] = d['types'].astype('str') 
d["columns"] = d["columns"].astype('str') 

str_feat = d[d["types"]=="String"]["columns"]

for feat in str_feat:
    print(feat)
    if "date" not in feat:
        ok = pd.unique(pd.Series(data[feat]))
        print(ok)
# Out:
# date_decision
# lastapprcommoditycat_1041M
# ['a55475b1' 'P159_130_59' 'P21_79_33' 'P12_6_178' 'P109_133_183'
#  'P53_45_92' 'P148_110_5' 'P33_29_177' 'P201_79_148' 'P100_96_175'
#  'P216_109_183' 'P143_21_170' 'P187_118_47' 'P128_43_169' 'P177_46_174'
#  'P105_126_172' 'P184_3_97' 'P121_6_80' 'P160_128_10' 'P65_94_74'
#  'P110_120_162' 'P52_56_90' 'P21_123_87' 'P181_140_94' 'P201_108_190'
#  'P193_109_73' 'P137_6_96' 'P48_73_87' 'P76_145_175' 'P3_103_80'
#  'P75_42_174' 'P49_162_170' 'P156_122_160' 'P175_82_175' 'P98_19_172'
#  'P156_50_173' 'P141_125_135' 'P117_143_46' 'P137_157_60' 'P126_161_96'
#  'P155_91_176' 'P38_69_128' 'P93_39_173' 'P58_25_91' 'P187_21_169']
# lastapprcommoditytypec_5251766M
# ['a55475b1' 'P126_18_172' 'P165_57_169' 'P70_143_178' 'P75_90_70'
#  'P174_113_42' 'P30_45_143' 'P123_124_181' 'P170_96_161' 'P49_111_165'
#  'P206_72_67' 'P161_88_182' 'P135_89_156' 'P79_131_167' 'P97_89_62'
#  'P200_75_140' 'P48_108_131' 'P98_55_164' 'P17_39_147' 'P111_89_135'
#  'P69_71_48' 'P142_50_170' 'P172_87_177' 'P218_111_186' 'P184_79_111'
#  'P11_14_152' 'P42_60_161' 'P128_13_121' 'P47_91_102' 'P149_85_125'
#  'P21_135_111' 'P132_130_54' 'P95_36_171' 'P171_142_104' 'P210_68_40'
#  'P16_51_146' 'P192_46_167' 'P108_95_156' 'P136_59_154' 'P122_61_164'
#  'P101_97_152' 'P110_105_93' 'P176_22_171' 'P97_70_52' 'P96_22_172'
#  'P2_128_156' 'P45_86_83' 'P99_150_162' 'P214_93_177' 'P5_163_186'
#  'P40_130_91' 'P137_154_119' 'P19_69_188' 'P108_57_165' 'P67_33_177'
#  'P3_101_79' 'P162_126_193' 'P79_78_118' 'P80_108_65' 'P179_147_79'
#  'P162_66_138' 'P36_136_102' 'P120_144_42' 'P193_129_4' 'P48_73_87'
#  'P78_110_79' 'P179_94_166' 'P217_49_170' 'P30_123_176' 'P94_74_111'
#  'P65_158_146' 'P198_70_54' 'P88_22_174' 'P146_17_171' 'P175_140_102'
#  'P216_127_49' 'P193_108_43' 'P31_98_120' 'P86_126_186' 'P105_66_162'
#  'P54_152_154' 'P211_30_165' 'P133_44_167' 'P49_127_19' 'P136_108_173'
#  'P87_135_164' 'P31_77_87' 'P167_25_171' 'P38_137_94' 'P218_84_167'
#  'P27_34_157' 'P133_91_178' 'P16_81_96' 'P82_105_64' 'P89_71_50'
#  'P109_39_170' 'P82_15_54' 'P61_107_116' 'P178_162_168' 'P136_95_178'
#  'P63_14_24' 'P162_155_169' 'P127_97_181' 'P214_125_25' 'P54_121_22'
#  'P18_55_149' 'P110_60_165' 'P107_30_170' 'P210_51_101' 'P199_161_73'
#  'P74_104_25' 'P97_153_169' 'P189_23_170' 'P73_74_80' 'P42_21_57'
#  'P21_87_50' 'P148_155_175' 'P104_14_35' 'P121_18_172' 'P126_138_175'
#  'P177_138_94' 'P54_85_123' 'P31_42_128' 'P81_94_108' 'P36_26_21'
#  'P106_139_158' 'P108_50_169' 'P86_0_60' 'P108_160_76' 'P21_84_40'
#  'P70_53_172' 'P156_54_111' 'P0_140_162']
# description_5085714M
# [None 'a55475b1' '2fc785b2']
# education_1103M
# [None 'a55475b1' '717ddd49' '6b2ae0fa' '39a0853f' 'c8e1a1d0']
# education_88M
# [None 'a55475b1' '6b2ae0fa' '717ddd49' 'a34a13c8' 'c8e1a1d0']
# maritalst_385M
# [None 'a55475b1' 'a7fcb6e5' '3439d993' 'b6cabe76' '38c061ee' 'ecd83604']
# maritalst_893M
# [None 'a55475b1' '46b968c3' '977b2a70' '1a19667c' 'e18430ff' 'ecd83604']
# person_housetype
# [None 'OWNED' 'FLAT' 'PARENTAL' 'COMPANY_FLAT' 'STATE_FLAT' 'COOP_FLAT']

# %%
test_person_1_feats_1 = test_person_1.group_by("case_id").agg(
    pl.col("mainoccupationinc_384A").max().alias("mainoccupationinc_384A_max"),
    (pl.col("incometype_1044T") == "SELFEMPLOYED").max().alias("mainoccupationinc_384A_any_selfemployed")
)

test_person_1_feats_2 = test_person_1.select(["case_id", "num_group1", "housetype_905L"]).filter(
    pl.col("num_group1") == 0
).drop("num_group1").rename({"housetype_905L": "person_housetype"})

test_credit_bureau_b_2_feats = test_credit_bureau_b_2.group_by("case_id").agg(
    pl.col("pmts_pmtsoverdue_635A").max().alias("pmts_pmtsoverdue_635A_max"),
    (pl.col("pmts_dpdvalue_108P") > 31).max().alias("pmts_dpdvalue_108P_over31")
)

data_submission = test_basetable.join(
    test_static.select(["case_id"]+selected_static_cols), how="left", on="case_id"
).join(
    test_static_cb.select(["case_id"]+selected_static_cb_cols), how="left", on="case_id"
).join(
    test_person_1_feats_1, how="left", on="case_id"
).join(
    test_person_1_feats_2, how="left", on="case_id"
).join(
    test_credit_bureau_b_2_feats, how="left", on="case_id"
)

# %%
data_submission.shape

# %%
case_ids = data["case_id"].unique().shuffle(seed=1)
case_ids_train, case_ids_test = train_test_split(case_ids, train_size=0.6, random_state=1)
case_ids_valid, case_ids_test = train_test_split(case_ids_test, train_size=0.5, random_state=1)

cols_pred = []
for col in data.columns:
    if col[-1].isupper() and col[:-1].islower():
        cols_pred.append(col)

print(cols_pred)

def from_polars_to_pandas(case_ids: pl.DataFrame) -> pl.DataFrame:
    return (
        data.filter(pl.col("case_id").is_in(case_ids))[["case_id", "WEEK_NUM", "target"]].to_pandas(),
        data.filter(pl.col("case_id").is_in(case_ids))[cols_pred].to_pandas(),
        data.filter(pl.col("case_id").is_in(case_ids))["target"].to_pandas()
    )

base_train, X_train, y_train = from_polars_to_pandas(case_ids_train)
base_valid, X_valid, y_valid = from_polars_to_pandas(case_ids_valid)
base_test, X_test, y_test = from_polars_to_pandas(case_ids_test)

for df in [X_train, X_valid, X_test]:
    df = convert_strings(df)
# Out:
# ['amtinstpaidbefduel24m_4187115A', 'annuity_780A', 'annuitynextmonth_57A', 'avginstallast24m_3658937A', 'avglnamtstart24m_4525187A', 'avgoutstandbalancel6m_4187114A', 'avgpmtlast12m_4525200A', 'credamount_770A', 'currdebt_22A', 'currdebtcredtyperange_828A', 'disbursedcredamount_1113A', 'downpmt_116A', 'inittransactionamount_650A', 'lastapprcommoditycat_1041M', 'lastapprcommoditytypec_5251766M', 'lastapprcredamount_781A', 'lastcancelreason_561M', 'lastotherinc_902A', 'lastotherlnsexpense_631A', 'lastrejectcommoditycat_161M', 'lastrejectcommodtypec_5251769M', 'lastrejectcredamount_222A', 'lastrejectreason_759M', 'lastrejectreasonclient_4145040M', 'maininc_215A', 'maxannuity_159A', 'maxannuity_4075009A', 'maxdebt4_972A', 'maxinstallast24m_3658928A', 'maxlnamtstart6m_4525199A', 'maxoutstandbalancel12m_4187113A', 'maxpmtlast3m_4525190A', 'previouscontdistrict_112M', 'price_1097A', 'sumoutstandtotal_3546847A', 'sumoutstandtotalest_4493215A', 'totaldebt_9A', 'totalsettled_863A', 'totinstallast1m_4525188A', 'description_5085714M', 'education_1103M', 'education_88M', 'maritalst_385M', 'maritalst_893M', 'pmtaverage_3A', 'pmtaverage_4527227A', 'pmtaverage_4955615A', 'pmtssum_45A']

# %%
print(f"Train: {X_train.shape}")
print(f"Valid: {X_valid.shape}")
print(f"Test: {X_test.shape}")

y_train.head()
# Out:
# Train: (915995, 48)
# Valid: (305332, 48)
# Test: (305332, 48)
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target, dtype: int64

# %% [markdown]
# ## Training LightGBM
#
# Minimal example of LightGBM training is shown below.

# %%
lgb_train = lgb.Dataset(X_train, label=y_train)
lgb_valid = lgb.Dataset(X_valid, label=y_valid, reference=lgb_train)

params = {
    "boosting_type": "gbdt",
    "objective": "binary",
    "metric": "auc",
    "max_depth": 3,
    "num_leaves": 31,
    "learning_rate": 0.05,
    "feature_fraction": 0.9,
    "bagging_fraction": 0.8,
    "bagging_freq": 5,
    "n_estimators": 1000,
    "verbose": -1,
}

gbm = lgb.train(
    params,
    lgb_train,
    valid_sets=lgb_valid,
    callbacks=[lgb.log_evaluation(50), lgb.early_stopping(10)]
)
# Out:
# C:\Users\Jan\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\lightgbm\engine.py:172: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# Training until validation scores don't improve for 10 rounds
# [50]	valid_0's auc: 0.705963
# [100]	valid_0's auc: 0.724362
# [150]	valid_0's auc: 0.731423
# [200]	valid_0's auc: 0.735874
# [250]	valid_0's auc: 0.739009
# [300]	valid_0's auc: 0.740965
# [350]	valid_0's auc: 0.742924
# [400]	valid_0's auc: 0.744582
# [450]	valid_0's auc: 0.745977
# [500]	valid_0's auc: 0.747033
# [550]	valid_0's auc: 0.747877
# [600]	valid_0's auc: 0.749039
# [650]	valid_0's auc: 0.750087
# [700]	valid_0's auc: 0.750863
# Early stopping, best iteration is:
# [739]	valid_0's auc: 0.751216

# %% [markdown]
# Evaluation with AUC and then comparison with the stability metric is shown below.

# %%
for base, X in [(base_train, X_train), (base_valid, X_valid), (base_test, X_test)]:
    y_pred = gbm.predict(X, num_iteration=gbm.best_iteration)
    base["score"] = y_pred

print(f'The AUC score on the train set is: {roc_auc_score(base_train["target"], base_train["score"])}') 
print(f'The AUC score on the valid set is: {roc_auc_score(base_valid["target"], base_valid["score"])}') 
print(f'The AUC score on the test set is: {roc_auc_score(base_test["target"], base_test["score"])}')  

print(base_train['score'])
# Out:
# The AUC score on the train set is: 0.764122917660593
# The AUC score on the valid set is: 0.7512157223309048
# The AUC score on the test set is: 0.7483072129459662
# 0         0.032251
# 1         0.041961
# 2         0.033620
# 3         0.063119
# 4         0.029488
#             ...
# 915990    0.076309
# 915991    0.006416
# 915992    0.022882
# 915993    0.003766
# 915994    0.004232
# Name: score, Length: 915995, dtype: float64

# %%
def gini_stability(base, w_fallingrate=88.0, w_resstd=-0.5):
    gini_in_time = base.loc[:, ["WEEK_NUM", "target", "score"]]\
        .sort_values("WEEK_NUM")\
        .groupby("WEEK_NUM")[["target", "score"]]\
        .apply(lambda x: 2*roc_auc_score(x["target"], x["score"])-1).tolist()
    
    x = np.arange(len(gini_in_time))
    y = gini_in_time
    a, b = np.polyfit(x, y, 1)
    y_hat = a*x + b
    residuals = y - y_hat
    res_std = np.std(residuals)
    avg_gini = np.mean(gini_in_time)
    return avg_gini + w_fallingrate * min(0, a) + w_resstd * res_std

stability_score_train = gini_stability(base_train)
stability_score_valid = gini_stability(base_valid)
stability_score_test = gini_stability(base_test)

print(f'The stability score on the train set is: {stability_score_train}') 
print(f'The stability score on the valid set is: {stability_score_valid}') 
print(f'The stability score on the test set is: {stability_score_test}')
# Out:
# The stability score on the train set is: 0.4976648127691175
# The stability score on the valid set is: 0.4726726686264489
# The stability score on the test set is: 0.4583643686935092

# %% [markdown]
# ## Submission
#
# Scoring the submission dataset is below, we need to take care of new categories. Then we save the score as a last step.

# %%
X_submission = data_submission[cols_pred].to_pandas()
X_submission = convert_strings(X_submission)
categorical_cols = X_train.select_dtypes(include=['category']).columns

for col in categorical_cols:
    train_categories = set(X_train[col].cat.categories)
    submission_categories = set(X_submission[col].cat.categories)
    new_categories = submission_categories - train_categories
    X_submission.loc[X_submission[col].isin(new_categories), col] = "Unknown"
    new_dtype = pd.CategoricalDtype(categories=train_categories, ordered=True)
    X_train[col] = X_train[col].astype(new_dtype)
    X_submission[col] = X_submission[col].astype(new_dtype)

y_submission_pred = gbm.predict(X_submission, num_iteration=gbm.best_iteration)

# %%
submission = pd.DataFrame({
    "case_id": data_submission["case_id"].to_numpy(),
    "score": y_submission_pred
}).set_index('case_id')
submission.to_csv("./submission.csv")
