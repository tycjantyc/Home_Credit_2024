# %%
import pandas as pd

df = pd.read_csv("../feature_definitions.csv")
print(df.columns)

print(df.to_string())
# Out:
# Index(['Variable', 'Description'], dtype='object')
#                             Variable                                                                                                                                                                                                            Description
# 0                     actualdpd_943P                                                                                                                                                                     Days Past Due (DPD) of previous contract (actual).
# 1            actualdpdtolerance_344P                                                                                                                                                                                          DPD of client with tolerance.
# ...

# %%
v = df[df["Variable"] == "lastapprcommoditycat_1041M"]["Description"].to_string()
print(v)
# Out:
# 231    Commodity category of the last loan applicatio...
